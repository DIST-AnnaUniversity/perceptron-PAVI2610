# %%
#This program is the implementation of example program of perceptron algorithm from Zurada's Introduction to Artificial Neural networks
#This uses continuous activation function
import math
import numpy as np
#/*----------------Function for perceptron algorithm --------------*/
def perceptron(c,X,d,w,iter,lam):
    for n in range(1,iter):# Number of iterations  = 7
        print ("Iteration ", n)
        print ("--------------")
        for i, x in enumerate(X):
            net = np.dot(X[i],w)
            out = (2/(1+math.exp(-lam*net)))-1
            r = c*(d[i] - out)*(1-(out*out))
            delta_w = 1/2*(r*x)
            w = delta_w+w
            print ("Step ", i, ":", w)
    return w
#/*---------------------Function for testing the perceptron-----------*/

def test_perceptron(final_out,X,w,lam):
    for i,x in enumerate(X):
        net = np.dot(X[i],w)
        out = (2/(1+math.exp(-lam*net)))-1
        final_out = final_out+[out]
    return final_out

#*---------------Training---------------------------------*/
X = np.array([[1,1],[-0.5,1],[3,1],[-2,1],])
new_input = np.array([[7,1],[-7,1],])#feed new inputs and see
print ("Inputs", X)
d = np.array([1,-1,1,-1])
print ("Teacher values", d)
w= ([0,0])
print ("initial values of weights", w)
c = 1
iterations = 7
lam=1
print ("Training")
print ("----------")
final_weight = perceptron(c,X,d,w,iterations,lam)
print ("Final sets of weights: ", final_weight)
#*-----------------Testing-------------------------------*/
final_out = []
print ("Testing")
print ("--------")
final_output = test_perceptron(final_out,new_input,final_weight,lam)
print ("Final output: ", final_output)
#print ("Original Teacher values", d)
# Out:
# Inputs [[ 1.   1. ]
#  [-0.5  1. ]
#  [ 3.   1. ]
#  [-2.   1. ]]
# Teacher values [ 1 -1  1 -1]
# initial values of weights [0, 0]
# Training
# ----------
# Iteration  1
# --------------
# Step  0 : [0.5 0.5]
# Step  1 : [ 0.77674159 -0.05348319]
# Step  2 : [ 0.87100722 -0.02206131]
# Step  3 : [ 1.01715044 -0.09513293]
# Iteration  2
# --------------
# Step  0 : [1.24886275 0.13657938]
# Step  1 : [ 1.42817996 -0.22205504]
# Step  2 : [ 1.43155535 -0.2209299 ]
# Step  3 : [ 1.44621127 -0.22825786]
# Iteration  3
# --------------
# Step  0 : [ 1.6070942  -0.06737492]
# Step  1 : [ 1.72984056 -0.31286764]
# Step  2 : [ 1.73052208 -0.31264046]
# Step  3 : [ 1.73446415 -0.3146115 ]
# Iteration  4
# --------------
# Step  0 : [ 1.8565568  -0.19251884]
# Step  1 : [ 1.94773014 -0.37486553]
# Step  2 : [ 1.94794099 -0.37479525]
# Step  3 : [ 1.94943912 -0.37554431]
# Iteration  5
# --------------
# Step  0 : [ 2.04707631 -0.27790711]
# Step  1 : [ 2.11902222 -0.42179894]
# Step  2 : [ 2.11910548 -0.42177118]
# Step  3 : [ 2.11980244 -0.42211966]
# Iteration  6
# --------------
# Step  0 : [ 2.2007864 -0.3411357]
# Step  1 : [ 2.25998102 -0.45952493]
# Step  2 : [ 2.26001966 -0.45951205]
# Step  3 : [ 2.26039032 -0.45969738]
# Final sets of weights:  [ 2.26039032 -0.45969738]
# Testing
# --------
# Final output:  [0.9999995744519063, -0.9999998303082882]
